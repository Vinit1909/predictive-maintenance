# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
plt.style.use('ggplot')
# %matplotlib inline

# %%
df_tr_lbl = pd.read_csv('train.csv')
df_tr_lbl.head()
# Out:
#    id  cycle  setting1  setting2  setting3      s1      s2       s3       s4  \
# 0   1      1   -0.0007   -0.0004     100.0  518.67  641.82  1589.70  1400.60
# 1   1      2    0.0019   -0.0003     100.0  518.67  642.15  1591.82  1403.14
# 2   1      3   -0.0043    0.0003     100.0  518.67  642.35  1587.99  1404.20
# 3   1      4    0.0007    0.0000     100.0  518.67  642.35  1582.79  1401.87
# 4   1      5   -0.0019   -0.0002     100.0  518.67  642.37  1582.85  1406.22
#
#       s5  ...    av15.1  av16.1    av17.1  av18.1  av19.1    av20.1    av21.1  \
# 0  14.62  ...  0.000000     0.0  0.000000     0.0     0.0  0.000000  0.000000
# 1  14.62  ...  0.008697     0.0  0.000000     0.0     0.0  0.042426  0.003253
# 2  14.62  ...  0.007640     0.0  1.154701     0.0     0.0  0.055076  0.044573
# 3  14.62  ...  0.028117     0.0  1.000000     0.0     0.0  0.076322  0.037977
# 4  14.62  ...  0.025953     0.0  1.095445     0.0     0.0  0.073621  0.033498
#
#    ttf  label_bnc  label_mcc
# 0  191          0          0
# 1  190          0          0
# 2  189          0          0
# 3  188          0          0
# 4  187          0          0
#
# [5 rows x 71 columns]

# %%
features = ['setting1','setting2','setting3','s1','s2','s3','s4','s5','s6','s7','s8','s9','s10','s11','s12','s13','s14','s15','s16','s17','s18','s19','s20','s21']

# %% [markdown]
# Plotting to compare the standard deviation of features

# %%
df_tr_lbl[features].std().plot(kind='bar', fig = (10,10),title = "Features Standard Deviation")
# Out:
# <AxesSubplot:title={'center':'Features Standard Deviation'}>

# %%
features_top_var = df_tr_lbl[features].std().sort_values(ascending=False)
features_top_var
# Out:
# s9          2.208288e+01
# s14         1.907618e+01
# s4          9.000605e+00
# s3          6.131150e+00
# s17         1.548763e+00
# s7          8.850923e-01
# s12         7.375534e-01
# s2          5.000533e-01
# s11         2.670874e-01
# s20         1.807464e-01
# s21         1.082509e-01
# s13         7.191892e-02
# s8          7.098548e-02
# s15         3.750504e-02
# setting1    2.187313e-03
# s6          1.388985e-03
# setting2    2.930621e-04
# s1          6.537152e-11
# s5          3.394700e-12
# s10         4.660829e-13
# s16         1.556432e-14
# s18         0.000000e+00
# s19         0.000000e+00
# setting3    0.000000e+00
# dtype: float64

# %%
df_tr_lbl[features].corrwith(df_tr_lbl.ttf).sort_values(ascending = False)
# Out:
# s12         6.719831e-01
# s7          6.572227e-01
# s21         6.356620e-01
# s20         6.294285e-01
# s16        -5.849749e-16
# s5         -5.849749e-16
# setting2   -1.947628e-03
# setting1   -3.198458e-03
# s6         -1.283484e-01
# s14        -3.067689e-01
# s9         -3.901016e-01
# s13        -5.625688e-01
# s8         -5.639684e-01
# s3         -5.845204e-01
# s17        -6.061536e-01
# s2         -6.064840e-01
# s15        -6.426670e-01
# s4         -6.789482e-01
# s11        -6.962281e-01
# setting3             NaN
# s1                   NaN
# s10                  NaN
# s18                  NaN
# s19                  NaN
# dtype: float64

# %%
low_cor_features = ['setting3','s1','s10','s18','s19','s16','s5','setting2','setting1']
df_tr_lbl[low_cor_features].describe()
# Out:
#        setting3            s1           s10      s18      s19           s16  \
# count   20631.0  2.063100e+04  2.063100e+04  20631.0  20631.0  2.063100e+04
# mean      100.0  5.186700e+02  1.300000e+00   2388.0    100.0  3.000000e-02
# std         0.0  6.537152e-11  4.660829e-13      0.0      0.0  1.556432e-14
# min       100.0  5.186700e+02  1.300000e+00   2388.0    100.0  3.000000e-02
# 25%       100.0  5.186700e+02  1.300000e+00   2388.0    100.0  3.000000e-02
# 50%       100.0  5.186700e+02  1.300000e+00   2388.0    100.0  3.000000e-02
# 75%       100.0  5.186700e+02  1.300000e+00   2388.0    100.0  3.000000e-02
# max       100.0  5.186700e+02  1.300000e+00   2388.0    100.0  3.000000e-02
#
#                  s5      setting2      setting1
# count  2.063100e+04  20631.000000  20631.000000
# mean   1.462000e+01      0.000002     -0.000009
# std    3.394700e-12      0.000293      0.002187
# min    1.462000e+01     -0.000600     -0.008700
# 25%    1.462000e+01     -0.000200     -0.001500
# 50%    1.462000e+01      0.000000      0.000000
# 75%    1.462000e+01      0.000300      0.001500
# max    1.462000e+01      0.000600      0.008700

# %%
correl_features = ['s12','s7','s21','s20','s6','s14','s9','s13','s8','s3','s17','s2','s15','s4','s11']
df_tr_lbl[correl_features].describe()
# Out:
#                 s12            s7           s21           s20            s6  \
# count  20631.000000  20631.000000  20631.000000  20631.000000  20631.000000
# mean     521.413470    553.367711     23.289705     38.816271     21.609803
# std        0.737553      0.885092      0.108251      0.180746      0.001389
# min      518.690000    549.850000     22.894200     38.140000     21.600000
# 25%      520.960000    552.810000     23.221800     38.700000     21.610000
# 50%      521.480000    553.440000     23.297900     38.830000     21.610000
# 75%      521.950000    554.010000     23.366800     38.950000     21.610000
# max      523.380000    556.060000     23.618400     39.430000     21.610000
#
#                 s14            s9           s13            s8            s3  \
# count  20631.000000  20631.000000  20631.000000  20631.000000  20631.000000
# mean    8143.752722   9065.242941   2388.096152   2388.096652   1590.523119
# std       19.076176     22.082880      0.071919      0.070985      6.131150
# min     8099.940000   9021.730000   2387.880000   2387.900000   1571.040000
# 25%     8133.245000   9053.100000   2388.040000   2388.050000   1586.260000
# 50%     8140.540000   9060.660000   2388.090000   2388.090000   1590.100000
# 75%     8148.310000   9069.420000   2388.140000   2388.140000   1594.380000
# max     8293.720000   9244.590000   2388.560000   2388.560000   1616.910000
#
#                 s17            s2           s15            s4           s11
# count  20631.000000  20631.000000  20631.000000  20631.000000  20631.000000
# mean     393.210654    642.680934      8.442146   1408.933782     47.541168
# std        1.548763      0.500053      0.037505      9.000605      0.267087
# min      388.000000    641.210000      8.324900   1382.250000     46.850000
# 25%      392.000000    642.325000      8.414900   1402.360000     47.350000
# 50%      393.000000    642.640000      8.438900   1408.040000     47.510000
# 75%      394.000000    643.000000      8.465600   1414.555000     47.700000
# max      400.000000    644.530000      8.584800   1441.490000     48.530000

# %%
correl_features_lbl = correl_features+['ttf']

# %%
import seaborn as sns
cm = np.corrcoef(df_tr_lbl[correl_features_lbl].values.T)
sns.set(font_scale=1.0)
fig = plt.figure(figsize=(20,20))
hm = sns.heatmap(cm,cbar = True, annot = True, square = True, fmt = '.2f', annot_kws = {'size':8},yticklabels=correl_features_lbl,xticklabels=correl_features_lbl)
plt.title('Features Correlation Heatmap')
# Out:
# Text(0.5, 1.0, 'Features Correlation Heatmap')

# %%
sns.reset_orig()

# %%
pd.plotting.scatter_matrix(df_tr_lbl[correl_features_lbl],alpha=0.2,figsize=(20,20),diagonal='kde')
# Out:
# array([[<AxesSubplot:xlabel='s12', ylabel='s12'>,
#         <AxesSubplot:xlabel='s7', ylabel='s12'>,
#         <AxesSubplot:xlabel='s21', ylabel='s12'>,
#         <AxesSubplot:xlabel='s20', ylabel='s12'>,
#         <AxesSubplot:xlabel='s6', ylabel='s12'>,
#         <AxesSubplot:xlabel='s14', ylabel='s12'>,
#         <AxesSubplot:xlabel='s9', ylabel='s12'>,
#         <AxesSubplot:xlabel='s13', ylabel='s12'>,
#         <AxesSubplot:xlabel='s8', ylabel='s12'>,
#         <AxesSubplot:xlabel='s3', ylabel='s12'>,
#         <AxesSubplot:xlabel='s17', ylabel='s12'>,
#         <AxesSubplot:xlabel='s2', ylabel='s12'>,
#         <AxesSubplot:xlabel='s15', ylabel='s12'>,
#         <AxesSubplot:xlabel='s4', ylabel='s12'>,
#         <AxesSubplot:xlabel='s11', ylabel='s12'>,
#         <AxesSubplot:xlabel='ttf', ylabel='s12'>],
#        [<AxesSubplot:xlabel='s12', ylabel='s7'>,
#         <AxesSubplot:xlabel='s7', ylabel='s7'>,
#         <AxesSubplot:xlabel='s21', ylabel='s7'>,
#         <AxesSubplot:xlabel='s20', ylabel='s7'>,
#         <AxesSubplot:xlabel='s6', ylabel='s7'>,
#         <AxesSubplot:xlabel='s14', ylabel='s7'>,
#         <AxesSubplot:xlabel='s9', ylabel='s7'>,
#         <AxesSubplot:xlabel='s13', ylabel='s7'>,
#         <AxesSubplot:xlabel='s8', ylabel='s7'>,
#         <AxesSubplot:xlabel='s3', ylabel='s7'>,
#         <AxesSubplot:xlabel='s17', ylabel='s7'>,
#         <AxesSubplot:xlabel='s2', ylabel='s7'>,
#         <AxesSubplot:xlabel='s15', ylabel='s7'>,
#         <AxesSubplot:xlabel='s4', ylabel='s7'>,
#         <AxesSubplot:xlabel='s11', ylabel='s7'>,
#         <AxesSubplot:xlabel='ttf', ylabel='s7'>],
#        [<AxesSubplot:xlabel='s12', ylabel='s21'>,
#         <AxesSubplot:xlabel='s7', ylabel='s21'>,
#         <AxesSubplot:xlabel='s21', ylabel='s21'>,
#         <AxesSubplot:xlabel='s20', ylabel='s21'>,
#         <AxesSubplot:xlabel='s6', ylabel='s21'>,
#         <AxesSubplot:xlabel='s14', ylabel='s21'>,
#         <AxesSubplot:xlabel='s9', ylabel='s21'>,
#         <AxesSubplot:xlabel='s13', ylabel='s21'>,
#         <AxesSubplot:xlabel='s8', ylabel='s21'>,
#         <AxesSubplot:xlabel='s3', ylabel='s21'>,
#         <AxesSubplot:xlabel='s17', ylabel='s21'>,
#         <AxesSubplot:xlabel='s2', ylabel='s21'>,
#         <AxesSubplot:xlabel='s15', ylabel='s21'>,
#         <AxesSubplot:xlabel='s4', ylabel='s21'>,
#         <AxesSubplot:xlabel='s11', ylabel='s21'>,
#         <AxesSubplot:xlabel='ttf', ylabel='s21'>],
#        [<AxesSubplot:xlabel='s12', ylabel='s20'>,
#         <AxesSubplot:xlabel='s7', ylabel='s20'>,
#         <AxesSubplot:xlabel='s21', ylabel='s20'>,
#         <AxesSubplot:xlabel='s20', ylabel='s20'>,
#         <AxesSubplot:xlabel='s6', ylabel='s20'>,
#         <AxesSubplot:xlabel='s14', ylabel='s20'>,
#         <AxesSubplot:xlabel='s9', ylabel='s20'>,
#         <AxesSubplot:xlabel='s13', ylabel='s20'>,
#         <AxesSubplot:xlabel='s8', ylabel='s20'>,
#         <AxesSubplot:xlabel='s3', ylabel='s20'>,
#         <AxesSubplot:xlabel='s17', ylabel='s20'>,
#         <AxesSubplot:xlabel='s2', ylabel='s20'>,
#         <AxesSubplot:xlabel='s15', ylabel='s20'>,
#         <AxesSubplot:xlabel='s4', ylabel='s20'>,
#         <AxesSubplot:xlabel='s11', ylabel='s20'>,
#         <AxesSubplot:xlabel='ttf', ylabel='s20'>],
#        [<AxesSubplot:xlabel='s12', ylabel='s6'>,
#         <AxesSubplot:xlabel='s7', ylabel='s6'>,
#         <AxesSubplot:xlabel='s21', ylabel='s6'>,
#         <AxesSubplot:xlabel='s20', ylabel='s6'>,
#         <AxesSubplot:xlabel='s6', ylabel='s6'>,
#         <AxesSubplot:xlabel='s14', ylabel='s6'>,
#         <AxesSubplot:xlabel='s9', ylabel='s6'>,
#         <AxesSubplot:xlabel='s13', ylabel='s6'>,
#         <AxesSubplot:xlabel='s8', ylabel='s6'>,
#         <AxesSubplot:xlabel='s3', ylabel='s6'>,
#         <AxesSubplot:xlabel='s17', ylabel='s6'>,
#         <AxesSubplot:xlabel='s2', ylabel='s6'>,
#         <AxesSubplot:xlabel='s15', ylabel='s6'>,
#         <AxesSubplot:xlabel='s4', ylabel='s6'>,
#         <AxesSubplot:xlabel='s11', ylabel='s6'>,
#         <AxesSubplot:xlabel='ttf', ylabel='s6'>],
#        [<AxesSubplot:xlabel='s12', ylabel='s14'>,
#         <AxesSubplot:xlabel='s7', ylabel='s14'>,
#         <AxesSubplot:xlabel='s21', ylabel='s14'>,
#         <AxesSubplot:xlabel='s20', ylabel='s14'>,
#         <AxesSubplot:xlabel='s6', ylabel='s14'>,
#         <AxesSubplot:xlabel='s14', ylabel='s14'>,
#         <AxesSubplot:xlabel='s9', ylabel='s14'>,
#         <AxesSubplot:xlabel='s13', ylabel='s14'>,
#         <AxesSubplot:xlabel='s8', ylabel='s14'>,
#         <AxesSubplot:xlabel='s3', ylabel='s14'>,
#         <AxesSubplot:xlabel='s17', ylabel='s14'>,
#         <AxesSubplot:xlabel='s2', ylabel='s14'>,
#         <AxesSubplot:xlabel='s15', ylabel='s14'>,
#         <AxesSubplot:xlabel='s4', ylabel='s14'>,
#         <AxesSubplot:xlabel='s11', ylabel='s14'>,
#         <AxesSubplot:xlabel='ttf', ylabel='s14'>],
#        [<AxesSubplot:xlabel='s12', ylabel='s9'>,
#         <AxesSubplot:xlabel='s7', ylabel='s9'>,
#         <AxesSubplot:xlabel='s21', ylabel='s9'>,
#         <AxesSubplot:xlabel='s20', ylabel='s9'>,
#         <AxesSubplot:xlabel='s6', ylabel='s9'>,
#         <AxesSubplot:xlabel='s14', ylabel='s9'>,
#         <AxesSubplot:xlabel='s9', ylabel='s9'>,
#         <AxesSubplot:xlabel='s13', ylabel='s9'>,
#         <AxesSubplot:xlabel='s8', ylabel='s9'>,
#         <AxesSubplot:xlabel='s3', ylabel='s9'>,
#         <AxesSubplot:xlabel='s17', ylabel='s9'>,
#         <AxesSubplot:xlabel='s2', ylabel='s9'>,
#         <AxesSubplot:xlabel='s15', ylabel='s9'>,
#         <AxesSubplot:xlabel='s4', ylabel='s9'>,
#         <AxesSubplot:xlabel='s11', ylabel='s9'>,
#         <AxesSubplot:xlabel='ttf', ylabel='s9'>],
#        [<AxesSubplot:xlabel='s12', ylabel='s13'>,
#         <AxesSubplot:xlabel='s7', ylabel='s13'>,
#         <AxesSubplot:xlabel='s21', ylabel='s13'>,
#         <AxesSubplot:xlabel='s20', ylabel='s13'>,
#         <AxesSubplot:xlabel='s6', ylabel='s13'>,
#         <AxesSubplot:xlabel='s14', ylabel='s13'>,
#         <AxesSubplot:xlabel='s9', ylabel='s13'>,
#         <AxesSubplot:xlabel='s13', ylabel='s13'>,
#         <AxesSubplot:xlabel='s8', ylabel='s13'>,
#         <AxesSubplot:xlabel='s3', ylabel='s13'>,
#         <AxesSubplot:xlabel='s17', ylabel='s13'>,
#         <AxesSubplot:xlabel='s2', ylabel='s13'>,
#         <AxesSubplot:xlabel='s15', ylabel='s13'>,
#         <AxesSubplot:xlabel='s4', ylabel='s13'>,
#         <AxesSubplot:xlabel='s11', ylabel='s13'>,
#         <AxesSubplot:xlabel='ttf', ylabel='s13'>],
#        [<AxesSubplot:xlabel='s12', ylabel='s8'>,
#         <AxesSubplot:xlabel='s7', ylabel='s8'>,
#         <AxesSubplot:xlabel='s21', ylabel='s8'>,
#         <AxesSubplot:xlabel='s20', ylabel='s8'>,
#         <AxesSubplot:xlabel='s6', ylabel='s8'>,
#         <AxesSubplot:xlabel='s14', ylabel='s8'>,
#         <AxesSubplot:xlabel='s9', ylabel='s8'>,
#         <AxesSubplot:xlabel='s13', ylabel='s8'>,
#         <AxesSubplot:xlabel='s8', ylabel='s8'>,
#         <AxesSubplot:xlabel='s3', ylabel='s8'>,
#         <AxesSubplot:xlabel='s17', ylabel='s8'>,
#         <AxesSubplot:xlabel='s2', ylabel='s8'>,
#         <AxesSubplot:xlabel='s15', ylabel='s8'>,
#         <AxesSubplot:xlabel='s4', ylabel='s8'>,
#         <AxesSubplot:xlabel='s11', ylabel='s8'>,
#         <AxesSubplot:xlabel='ttf', ylabel='s8'>],
#        [<AxesSubplot:xlabel='s12', ylabel='s3'>,
#         <AxesSubplot:xlabel='s7', ylabel='s3'>,
#         <AxesSubplot:xlabel='s21', ylabel='s3'>,
#         <AxesSubplot:xlabel='s20', ylabel='s3'>,
#         <AxesSubplot:xlabel='s6', ylabel='s3'>,
#         <AxesSubplot:xlabel='s14', ylabel='s3'>,
#         <AxesSubplot:xlabel='s9', ylabel='s3'>,
#         <AxesSubplot:xlabel='s13', ylabel='s3'>,
#         <AxesSubplot:xlabel='s8', ylabel='s3'>,
#         <AxesSubplot:xlabel='s3', ylabel='s3'>,
#         <AxesSubplot:xlabel='s17', ylabel='s3'>,
#         <AxesSubplot:xlabel='s2', ylabel='s3'>,
#         <AxesSubplot:xlabel='s15', ylabel='s3'>,
#         <AxesSubplot:xlabel='s4', ylabel='s3'>,
#         <AxesSubplot:xlabel='s11', ylabel='s3'>,
#         <AxesSubplot:xlabel='ttf', ylabel='s3'>],
#        [<AxesSubplot:xlabel='s12', ylabel='s17'>,
#         <AxesSubplot:xlabel='s7', ylabel='s17'>,
#         <AxesSubplot:xlabel='s21', ylabel='s17'>,
#         <AxesSubplot:xlabel='s20', ylabel='s17'>,
#         <AxesSubplot:xlabel='s6', ylabel='s17'>,
#         <AxesSubplot:xlabel='s14', ylabel='s17'>,
#         <AxesSubplot:xlabel='s9', ylabel='s17'>,
#         <AxesSubplot:xlabel='s13', ylabel='s17'>,
#         <AxesSubplot:xlabel='s8', ylabel='s17'>,
#         <AxesSubplot:xlabel='s3', ylabel='s17'>,
#         <AxesSubplot:xlabel='s17', ylabel='s17'>,
#         <AxesSubplot:xlabel='s2', ylabel='s17'>,
#         <AxesSubplot:xlabel='s15', ylabel='s17'>,
#         <AxesSubplot:xlabel='s4', ylabel='s17'>,
#         <AxesSubplot:xlabel='s11', ylabel='s17'>,
#         <AxesSubplot:xlabel='ttf', ylabel='s17'>],
#        [<AxesSubplot:xlabel='s12', ylabel='s2'>,
#         <AxesSubplot:xlabel='s7', ylabel='s2'>,
#         <AxesSubplot:xlabel='s21', ylabel='s2'>,
#         <AxesSubplot:xlabel='s20', ylabel='s2'>,
#         <AxesSubplot:xlabel='s6', ylabel='s2'>,
#         <AxesSubplot:xlabel='s14', ylabel='s2'>,
#         <AxesSubplot:xlabel='s9', ylabel='s2'>,
#         <AxesSubplot:xlabel='s13', ylabel='s2'>,
#         <AxesSubplot:xlabel='s8', ylabel='s2'>,
#         <AxesSubplot:xlabel='s3', ylabel='s2'>,
#         <AxesSubplot:xlabel='s17', ylabel='s2'>,
#         <AxesSubplot:xlabel='s2', ylabel='s2'>,
#         <AxesSubplot:xlabel='s15', ylabel='s2'>,
#         <AxesSubplot:xlabel='s4', ylabel='s2'>,
#         <AxesSubplot:xlabel='s11', ylabel='s2'>,
#         <AxesSubplot:xlabel='ttf', ylabel='s2'>],
#        [<AxesSubplot:xlabel='s12', ylabel='s15'>,
#         <AxesSubplot:xlabel='s7', ylabel='s15'>,
#         <AxesSubplot:xlabel='s21', ylabel='s15'>,
#         <AxesSubplot:xlabel='s20', ylabel='s15'>,
#         <AxesSubplot:xlabel='s6', ylabel='s15'>,
#         <AxesSubplot:xlabel='s14', ylabel='s15'>,
#         <AxesSubplot:xlabel='s9', ylabel='s15'>,
#         <AxesSubplot:xlabel='s13', ylabel='s15'>,
#         <AxesSubplot:xlabel='s8', ylabel='s15'>,
#         <AxesSubplot:xlabel='s3', ylabel='s15'>,
#         <AxesSubplot:xlabel='s17', ylabel='s15'>,
#         <AxesSubplot:xlabel='s2', ylabel='s15'>,
#         <AxesSubplot:xlabel='s15', ylabel='s15'>,
#         <AxesSubplot:xlabel='s4', ylabel='s15'>,
#         <AxesSubplot:xlabel='s11', ylabel='s15'>,
#         <AxesSubplot:xlabel='ttf', ylabel='s15'>],
#        [<AxesSubplot:xlabel='s12', ylabel='s4'>,
#         <AxesSubplot:xlabel='s7', ylabel='s4'>,
#         <AxesSubplot:xlabel='s21', ylabel='s4'>,
#         <AxesSubplot:xlabel='s20', ylabel='s4'>,
#         <AxesSubplot:xlabel='s6', ylabel='s4'>,
#         <AxesSubplot:xlabel='s14', ylabel='s4'>,
#         <AxesSubplot:xlabel='s9', ylabel='s4'>,
#         <AxesSubplot:xlabel='s13', ylabel='s4'>,
#         <AxesSubplot:xlabel='s8', ylabel='s4'>,
#         <AxesSubplot:xlabel='s3', ylabel='s4'>,
#         <AxesSubplot:xlabel='s17', ylabel='s4'>,
#         <AxesSubplot:xlabel='s2', ylabel='s4'>,
#         <AxesSubplot:xlabel='s15', ylabel='s4'>,
#         <AxesSubplot:xlabel='s4', ylabel='s4'>,
#         <AxesSubplot:xlabel='s11', ylabel='s4'>,
#         <AxesSubplot:xlabel='ttf', ylabel='s4'>],
#        [<AxesSubplot:xlabel='s12', ylabel='s11'>,
#         <AxesSubplot:xlabel='s7', ylabel='s11'>,
#         <AxesSubplot:xlabel='s21', ylabel='s11'>,
#         <AxesSubplot:xlabel='s20', ylabel='s11'>,
#         <AxesSubplot:xlabel='s6', ylabel='s11'>,
#         <AxesSubplot:xlabel='s14', ylabel='s11'>,
#         <AxesSubplot:xlabel='s9', ylabel='s11'>,
#         <AxesSubplot:xlabel='s13', ylabel='s11'>,
#         <AxesSubplot:xlabel='s8', ylabel='s11'>,
#         <AxesSubplot:xlabel='s3', ylabel='s11'>,
#         <AxesSubplot:xlabel='s17', ylabel='s11'>,
#         <AxesSubplot:xlabel='s2', ylabel='s11'>,
#         <AxesSubplot:xlabel='s15', ylabel='s11'>,
#         <AxesSubplot:xlabel='s4', ylabel='s11'>,
#         <AxesSubplot:xlabel='s11', ylabel='s11'>,
#         <AxesSubplot:xlabel='ttf', ylabel='s11'>],
#        [<AxesSubplot:xlabel='s12', ylabel='ttf'>,
#         <AxesSubplot:xlabel='s7', ylabel='ttf'>,
#         <AxesSubplot:xlabel='s21', ylabel='ttf'>,
#         <AxesSubplot:xlabel='s20', ylabel='ttf'>,
#         <AxesSubplot:xlabel='s6', ylabel='ttf'>,
#         <AxesSubplot:xlabel='s14', ylabel='ttf'>,
#         <AxesSubplot:xlabel='s9', ylabel='ttf'>,
#         <AxesSubplot:xlabel='s13', ylabel='ttf'>,
#         <AxesSubplot:xlabel='s8', ylabel='ttf'>,
#         <AxesSubplot:xlabel='s3', ylabel='ttf'>,
#         <AxesSubplot:xlabel='s17', ylabel='ttf'>,
#         <AxesSubplot:xlabel='s2', ylabel='ttf'>,
#         <AxesSubplot:xlabel='s15', ylabel='ttf'>,
#         <AxesSubplot:xlabel='s4', ylabel='ttf'>,
#         <AxesSubplot:xlabel='s11', ylabel='ttf'>,
#         <AxesSubplot:xlabel='ttf', ylabel='ttf'>]], dtype=object)

# %%
def explore_col(s,e):
    fig = plt.figure(figsize = (10,8))
    
    sub1 = fig.add_subplot(221)
    sub1.set_title(s+ 'histogram')
    sub1.hist(df_tr_lbl[s])
    
    sub2 = fig.add_subplot(222)
    sub2.set_title(s+ 'boxplot')
    sub2.boxplot(df_tr_lbl[s])
    
    if e>100 or e<=0:
        select_engines = list(pd.unique(df_tr_lbl.id))
    else:
        select_engines = np.random.choice(range(1,101),e,replace = False)
        
    sub3 = fig.add_subplot(223)
    sub3.set_title('time series: '+ s + '/cycle')
    sub3.set_xlabel('cycle')
    for i in select_engines:
        df = df_tr_lbl[['cycle',s]][df_tr_lbl.id == i]
        sub3.plot(df['cycle'],df[s])
    
    sub4 = fig.add_subplot(224)
    sub4.set_title('scatter: ' + s + '/ttf(regr label)')
    sub4.set_xlabel('ttf')
    sub4.scatter(df_tr_lbl['ttf'],df_tr_lbl[s])
    
    plt.tight_layout()
    plt.show()

# %%
explore_col('s12',10)

# %%
explore_col('s11',10)

# %%
explore_col('s6',10)

# %%
explore_col('s7',10)

# %%
explore_col('s9',10)

# %%
def plot_time_series(s):
    fig,axes = plt.subplots(10,1,sharex = True,figsize = (15,15))
    fig.subtitle = (s+'time series / cycle')
    
    select_engines = np.random.choice(range(1,101),10,replace = False).tolist()
    
    for e_id in select_engines:
        df = df_tr_lbl[['cycle',s]][df_tr_lbl.id == e_id]
        i = select_engines.index(e_id)
        axes[i].plot(df['cycle'],df[s])
        axes[i].set_ylabel('engine ' +str(e_id))
        axes[i].set_xlabel('cycle')
        
    plt.subplots_adjust(wspace=0,hspace=0)
    plt.show()

# %%
plot_time_series('s9')

# %%
plot_time_series('s7')

# %%
plot_time_series('s11')

# %%
print(df_tr_lbl['label_bnc'].value_counts())
print('\nNegative samples = {0:.0%}'.format(df_tr_lbl['label_bnc'].value_counts()[0]/df_tr_lbl['label_bnc'].count()))
print('\nPositive samples = {0:.0%}'.format(df_tr_lbl['label_bnc'].value_counts()[1]/df_tr_lbl['label_bnc'].count()))
# Out:
# 0    17531
# 1     3100
# Name: label_bnc, dtype: int64
#
# Negative samples = 85%
#
# Positive samples = 15%
